# %% [markdown]
# <a href="https://colab.research.google.com/github/ashokmulchandani/CUDA-GPU-Colab-Computer-Vision-Project-Ashok-1/blob/main/LIdar_vs_Photogrammetry_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# List what's in your Drive (adjust path based on where the folder is)
# !ls "/content/drive/MyDrive/"
# Out:
# '~$Udacity_k_best_machine_learning_scores_29_Nov_2018_Asha.xlsx'
#  AAAA_Prisha_Google_Drive_17_Sept_25
#  AAA_Ashok_Durga_Transport
# 'Air India Web Booking eTicket (NHN2VW) - ASHOK.pdf'
#  airtel_recharge
#  Ajay
#  A_machine_learning_after_indexing
# 'Appendix 2.1g Re-enrolment Form 2024.docx'
#  ASHA_CBA
#  Asha_CBA_Appraisal
#  ASHA_CBA_IOS
#  Asha_CBA_last_working_day
#  Asha_CBA_Offer_Letter_Lead_2021
#  Asha_Citiban_KYC_17_May_20
#  Asha_Google_drive
#  Asha_google_interview_20_May_19.xlsx
# 'Asha ICICI'
#  Asha_Issrani_Chapter_lead.gdoc
# 'ASHA ISSRANI PAYMENT METHODS 2024.pdf'
#  Asha_Issrani_Renewal_Passport_Sydney_MArch_2018
#  Asha_Pixel_return
# 'Asha_updated_Resume_Specialist_with ITS.gdoc'
#  Ashok_certificates
#  Ashok_hdfc
# 'Ashok-Job Application N8n-Agent - Tracker.gsheet'
#  Ashok_New_passport_Application
#  Ashok_old_images
#  Ashok_PMP_Maths.docx
#  Ashok_sydney_live_events
#  August_jobs_2018
# 'Balloon voucher adrenaline '
# 'based on the sructure in the word file attached c....gsheet'
#  Bhawna_employer_insurance_Feb_18
#  Bias
#  Bot_Experiment_Noble_Oak
#  Bupa_payments
# 'by_four_LORD Ganesh Ji Aarti.docx'
#  Canada_bay_council
# 'Can just give Area and growth percentage table on... (1).gsheet'
# 'Can just give Area and growth percentage table on....gsheet'
# 'Can you give a the list in the form of a 2 column... (1).gsheet'
# 'Can you give a the list in the form of a 2 column....gsheet'
# 'Can you give list of risks and their mitigation i....gsheet'
# 'Can you give  list of stakeholders and and their....gsheet'
# 'can you give me word count for it.gdoc'
# 'Can you read the below and give me story board fo....gsheet'
# 'Can you write a description column right next to....gsheet'
#  CBA_PaySlips.zip
#  CCS_income_estimate
#  Central_academy_hemant
#  central_coast_council
#  Chatkaaz_test.gsheet
#  chatkazz
#  Chatkazz
#  ChatkazzDoorHAng.png
#  Cloud_strategy
#  club
# 'Colab Notebooks'
#  Continuous_Improvement_Projects_Manager_04_Dec_2018_AC_MFG_med.doc
#  Continuous_Improvement_Projects_Manager_Ashok_Mulchandani_04_Dec_2018_AC_MFG_med.doc
#  Continuous_Improvement_Proje.textClipping
#  Continuous_Improvement_specialist_Manager_Ashok_Mulchandani_05_Dec_2018_NM_AC_BA_MFG.doc
# 'Copy of SWOT Analysis Background PPT Template.gslides'
# 'Copy of SWOT Analysis for Employees.pptx'
# 'Copy of SWOT Analysis for Students.pptx'
# 'Copy of Swot Analysis for Training and Development PPT  (1).gslides'
# "Couldn't find it can you highlight that what you....gdoc"
#  Cover_letter_Ashok
#  Discussion_with_HArvey_nornam_interview_31_july_2019_IMG_1991.JPG
#  DMAIC.pdf
#  Driving_license_renew_ashok_25_dec_19
#  dropbox_01_dec_2017
#  dropbox_28_june_2017
#  Durga_Payments_required
#  durga_transport
#  e_companies_Business_name
#  educate_child
#  EN-us-drchuck
# 'Epson Connect'
#  Exercise_New_Zealnd
# 'Expense sheet Cricket match India Vs Aus.gsheet'
# 'Explore and develop'
#  facebook
#  Fingal_Bay_Expense_Ashok.gsheet
# 'first day of the rain.gdoc'
#  firststate_super
#  First_state_super
#  fiverr
#  flybuys_redeem
#  from_linda_M_property_waitara
#  FSPR
# 'GE_Senior System Architect (non IT) job in Greenville, South Carolina, United States _ Product Management jobs at GE.pdf'
# 'Google AI Studio'
# 'google personalisation products overview.mp4'
# 'Home Expense.gsheet'
#  HomeFoo
#  HomeFoo.mp4
#  HR_block_consent
#  ICICI_FATCA_25_april_2019
# 'Identify main stakeholders and explain how your t....gsheet'
#  iitm
#  IIT_Madras_fee_Ashok_Jan_May_2021_3100_paid_14_march_21.pdf
# 'IIT_remote_proxy_Remote Proxy Setup _ P.G. Senapathy center for computing resource.pdf'
#  IMG_20250425_104817.jpg
# 'IMMI Grant Notification.pdf'
#  India_Singapore_travel_18_Oct_2019
# 'I need to file LCA as I am an australian citizen....gdoc'
# 'In the table above you  have made with clause and... (1).gsheet'
# 'In the table above you  have made with clause and....gsheet'
#  Iphone_7Plus_Ashok_contacts_vcf_768
#  ISO_9001:2008_manual
#  itrainer1360_shut_27_sept_2018
#  Jeet_bhawana_Ashok_Mutual
#  Jeetmulchandani_gmail_contact_list
#  Jitendra_Aditya_birla_SIP_reversal_19_Nov_2018.pdf
#  Jitu_krisha_30_oct_2019
#  Justice_NSW_13_June_2018
#  karma
#  LIC_receipts
#  Line_Site_Assessment_Report_Linen_15_july_2015_REV_1.pptx
#  Linkedin_Downloads
#  linkedin_image_19_aug_20
# 'LORD Ganesh Ji Aarti.docx'
# 'L&T_payslip'
#  Machine_learning
# 'Managing risks is paramount in construction proje....gsheet'
#  mars_wrigley_asquith
# 'meaning of my words'
# 'meanings of words'
# 'meanings of words (1)'
#  Misceleneous
#  MISCELLENEOUS_GOOGLE_DRIVE
#  Monaval_Night_market_expense.gsheet
#  Movie_twinkle_asha_drive
#  mri20aurion
#  mundan_prisha_11_Dec_17
#  MY_HP-laptop
# 'my letter.gdoc'
# 'my mother'
#  n8n_test
# 'Nirvi Mulchandani Developmental Summary May 2024.docx'
#  NishitAPK
#  Non_filing_of_income_tax_india_29_march_2018
#  opt_out_ehealth_Australia
#  Others_when_required
#  PanelCourseDetails_Ashok_marksheet_IIT_madard_17_July_2020_.pdf
#  papa_driving_license_renewal_march_2018
#  Papa_fortis_jaipur
#  PaymentStatus_jan_may_2020_iit_madras_declined.pdf
#  PaymentStatus_jan_may_2020_iit_madras_success_15_feb_2020.pdf
#  Physical_Activity_Australia
#  Pianorama-Junior-Course-Book-4-MP3s.zip
#  pizza
# 'Please convert this into a bar graph with labales.gsheet'
# 'Please the infromation below Armadale'$'\t''VIC'$'\t''3143'$'\n''Br....gsheet'
#  Ponytail
#  presentation_IO_AI_tool.gslides
# 'Prisha2nd Birthday.mp4'
#  prisha_birthday_2020_3_years
#  Prisha_Cake_Smash
#  Prisha_cake_smash_photo_high_res_Jan_18
#  Prisha_Dance_class_enrollment
#  Prisha_Dec_2018_exlore_and_develop
#  Prisha_Folder_Rainbow
#  Prisha_KU_wahroonga
#  Prisha_Next_Generation_day_care_27_May_2017
#  Prisha_photoshoot_Sept_2017
#  Prisha_Piano_ISM_turramurra
#  Prisha_rhythmic
#  Prisha_School_forms_Waitara
#  Prisha_Singing-Sargam.gdoc
# "Prisha's_Medical_records"
#  Prisha_swim_barker
#  PSD
#  Python_Assignments
#  Rajasthan_health_2020
#  RENEW_DL_2019_Asha_Ashok
#  Research_IOT
#  RRV_Australia_Asha_Ashok_15_Sept_2019
#  Salvation_Army
#  sbi_card_24_dec_2019
#  sbicard_googledrive_24_Sept_17
#  SBI_payments_July_2020
#  Seagate_hardrive_replacement_10_Jan_2019
#  Serco_07_Sept_2017
#  Serco_docs_for_Mike
#  SERCO_PERCEPTOR_DOCS
#  Shared_by_Pradeep_to_me_for_Aurion
#  share_market_and_sharepoint_pmi
#  SignEasy-Backup
#  Standard_work_unipart__8april19
#  Statement20191031.pdf
#  Statement_FEB2024_712562514.pdf
#  Steel_blue_boots_2.JPG
# 'Story Explanation and Vocabulary List.gsheet'
#  Tax_Australia
#  Tax_Australia_2018_2019
#  Tax_Australia_2020
#  Tax_Australia_2021_filed_in_2022
#  Tax_Australia_2022_filed_in_2023
#  Tax_bankStatements
#  test_data_collection.gform
#  TFN_Ashok_Tax_File_Number_Australia.pdf
#  theletter
# 'This looks great. Instead of paragraph write bull....gdoc'
#  Toyota_camry_2020_2021_renew
#  Toyota_camry_car_insurance_2018_renew
#  Toyota_RENEW_QBE_REGO_NMA_insurance_2019_10
#  Travel_India_24_jan_17
#  Udacity_k_best_machine_learning_scores_29_Nov_2018_Asha.xlsx
#  udemy_courses
# 'Underwriter_Application_Mr John Smith'
#  Unipart_work
# 'Untitled document (1).gdoc'
# 'Untitled document (2).gdoc'
# 'Untitled document (3).gdoc'
# 'Untitled document (4).gdoc'
# 'Untitled document (5).gdoc'
# 'Untitled document (6).gdoc'
# 'Untitled document (7).gdoc'
# 'Untitled document (8).gdoc'
# 'Untitled document.gdoc'
# 'Untitled form.gform'
# 'Untitled spreadsheet.gsheet'
#  westernunion_googledrive
#  willoughby_council
# 'Копия "Green Weekly Meal Planner".gsheet'

# %%
# Try this (adjust the path to match your folder name)
# !find "/content/drive/MyDrive" -maxdepth 2 -name "*.las" -o -name "*.ply" -o -name "*.pcd" -o -name "*.xyz" -o -name "*.bin" 2>/dev/null | head -20

# %%
from google.colab import drive
drive.mount('/content/drive')

# Then browse to find it
# !ls "/content/drive/MyDrive/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# '~$Udacity_k_best_machine_learning_scores_29_Nov_2018_Asha.xlsx'
#  AAAA_Prisha_Google_Drive_17_Sept_25
#  AAA_Ashok_Durga_Transport
# 'Air India Web Booking eTicket (NHN2VW) - ASHOK.pdf'
#  airtel_recharge
#  Ajay
#  A_machine_learning_after_indexing
# 'Appendix 2.1g Re-enrolment Form 2024.docx'
#  ASHA_CBA
#  Asha_CBA_Appraisal
#  ASHA_CBA_IOS
#  Asha_CBA_last_working_day
#  Asha_CBA_Offer_Letter_Lead_2021
#  Asha_Citiban_KYC_17_May_20
#  Asha_Google_drive
#  Asha_google_interview_20_May_19.xlsx
# 'Asha ICICI'
#  Asha_Issrani_Chapter_lead.gdoc
# 'ASHA ISSRANI PAYMENT METHODS 2024.pdf'
#  Asha_Issrani_Renewal_Passport_Sydney_MArch_2018
#  Asha_Pixel_return
# 'Asha_updated_Resume_Specialist_with ITS.gdoc'
#  Ashok_certificates
#  Ashok_hdfc
# 'Ashok-Job Application N8n-Agent - Tracker.gsheet'
#  Ashok_New_passport_Application
#  Ashok_old_images
#  Ashok_PMP_Maths.docx
#  Ashok_sydney_live_events
#  August_jobs_2018
# 'Balloon voucher adrenaline '
# 'based on the sructure in the word file attached c....gsheet'
#  Bhawna_employer_insurance_Feb_18
#  Bias
#  Bot_Experiment_Noble_Oak
#  Bupa_payments
# 'by_four_LORD Ganesh Ji Aarti.docx'
#  Canada_bay_council
# 'Can just give Area and growth percentage table on... (1).gsheet'
# 'Can just give Area and growth percentage table on....gsheet'
# 'Can you give a the list in the form of a 2 column... (1).gsheet'
# 'Can you give a the list in the form of a 2 column....gsheet'
# 'Can you give list of risks and their mitigation i....gsheet'
# 'Can you give  list of stakeholders and and their....gsheet'
# 'can you give me word count for it.gdoc'
# 'Can you read the below and give me story board fo....gsheet'
# 'Can you write a description column right next to....gsheet'
#  CBA_PaySlips.zip
#  CCS_income_estimate
#  Central_academy_hemant
#  central_coast_council
#  Chatkaaz_test.gsheet
#  chatkazz
#  Chatkazz
#  ChatkazzDoorHAng.png
#  Cloud_strategy
#  club
# 'Colab Notebooks'
#  Continuous_Improvement_Projects_Manager_04_Dec_2018_AC_MFG_med.doc
#  Continuous_Improvement_Projects_Manager_Ashok_Mulchandani_04_Dec_2018_AC_MFG_med.doc
#  Continuous_Improvement_Proje.textClipping
#  Continuous_Improvement_specialist_Manager_Ashok_Mulchandani_05_Dec_2018_NM_AC_BA_MFG.doc
# 'Copy of SWOT Analysis Background PPT Template.gslides'
# 'Copy of SWOT Analysis for Employees.pptx'
# 'Copy of SWOT Analysis for Students.pptx'
# 'Copy of Swot Analysis for Training and Development PPT  (1).gslides'
# "Couldn't find it can you highlight that what you....gdoc"
#  Cover_letter_Ashok
#  Discussion_with_HArvey_nornam_interview_31_july_2019_IMG_1991.JPG
#  DMAIC.pdf
#  Driving_license_renew_ashok_25_dec_19
#  dropbox_01_dec_2017
#  dropbox_28_june_2017
#  Durga_Payments_required
#  durga_transport
#  e_companies_Business_name
#  educate_child
#  EN-us-drchuck
# 'Epson Connect'
#  Exercise_New_Zealnd
# 'Expense sheet Cricket match India Vs Aus.gsheet'
# 'Explore and develop'
#  facebook
#  Fingal_Bay_Expense_Ashok.gsheet
# 'first day of the rain.gdoc'
#  firststate_super
#  First_state_super
#  fiverr
#  flybuys_redeem
#  from_linda_M_property_waitara
#  FSPR
# 'GE_Senior System Architect (non IT) job in Greenville, South Carolina, United States _ Product Management jobs at GE.pdf'
# 'Google AI Studio'
# 'google personalisation products overview.mp4'
# 'Home Expense.gsheet'
#  HomeFoo
#  HomeFoo.mp4
#  HR_block_consent
#  ICICI_FATCA_25_april_2019
# 'Identify main stakeholders and explain how your t....gsheet'
#  iitm
#  IIT_Madras_fee_Ashok_Jan_May_2021_3100_paid_14_march_21.pdf
# 'IIT_remote_proxy_Remote Proxy Setup _ P.G. Senapathy center for computing resource.pdf'
#  IMG_20250425_104817.jpg
# 'IMMI Grant Notification.pdf'
#  India_Singapore_travel_18_Oct_2019
# 'I need to file LCA as I am an australian citizen....gdoc'
# 'In the table above you  have made with clause and... (1).gsheet'
# 'In the table above you  have made with clause and....gsheet'
#  Iphone_7Plus_Ashok_contacts_vcf_768
#  ISO_9001:2008_manual
#  itrainer1360_shut_27_sept_2018
#  Jeet_bhawana_Ashok_Mutual
#  Jeetmulchandani_gmail_contact_list
#  Jitendra_Aditya_birla_SIP_reversal_19_Nov_2018.pdf
#  Jitu_krisha_30_oct_2019
#  Justice_NSW_13_June_2018
#  karma
#  LIC_receipts
#  Line_Site_Assessment_Report_Linen_15_july_2015_REV_1.pptx
#  Linkedin_Downloads
#  linkedin_image_19_aug_20
# 'LORD Ganesh Ji Aarti.docx'
# 'L&T_payslip'
#  Machine_learning
# 'Managing risks is paramount in construction proje....gsheet'
#  mars_wrigley_asquith
# 'meaning of my words'
# 'meanings of words'
# 'meanings of words (1)'
#  Misceleneous
#  MISCELLENEOUS_GOOGLE_DRIVE
#  Monaval_Night_market_expense.gsheet
#  Movie_twinkle_asha_drive
#  mri20aurion
#  mundan_prisha_11_Dec_17
#  MY_HP-laptop
# 'my letter.gdoc'
# 'my mother'
#  n8n_test
# 'Nirvi Mulchandani Developmental Summary May 2024.docx'
#  NishitAPK
#  Non_filing_of_income_tax_india_29_march_2018
#  opt_out_ehealth_Australia
#  Others_when_required
#  PanelCourseDetails_Ashok_marksheet_IIT_madard_17_July_2020_.pdf
#  papa_driving_license_renewal_march_2018
#  Papa_fortis_jaipur
#  PaymentStatus_jan_may_2020_iit_madras_declined.pdf
#  PaymentStatus_jan_may_2020_iit_madras_success_15_feb_2020.pdf
# 'Photogrammetry VS LiDAR Data Sets'
#  Physical_Activity_Australia
#  Pianorama-Junior-Course-Book-4-MP3s.zip
#  pizza
# 'Please convert this into a bar graph with labales.gsheet'
# 'Please the infromation below Armadale'$'\t''VIC'$'\t''3143'$'\n''Br....gsheet'
#  Ponytail
#  presentation_IO_AI_tool.gslides
# 'Prisha2nd Birthday.mp4'
#  prisha_birthday_2020_3_years
#  Prisha_Cake_Smash
#  Prisha_cake_smash_photo_high_res_Jan_18
#  Prisha_Dance_class_enrollment
#  Prisha_Dec_2018_exlore_and_develop
#  Prisha_Folder_Rainbow
#  Prisha_KU_wahroonga
#  Prisha_Next_Generation_day_care_27_May_2017
#  Prisha_photoshoot_Sept_2017
#  Prisha_Piano_ISM_turramurra
#  Prisha_rhythmic
#  Prisha_School_forms_Waitara
#  Prisha_Singing-Sargam.gdoc
# "Prisha's_Medical_records"
#  Prisha_swim_barker
#  PSD
#  Python_Assignments
#  Rajasthan_health_2020
#  RENEW_DL_2019_Asha_Ashok
#  Research_IOT
#  RRV_Australia_Asha_Ashok_15_Sept_2019
#  Salvation_Army
#  sbi_card_24_dec_2019
#  sbicard_googledrive_24_Sept_17
#  SBI_payments_July_2020
#  Seagate_hardrive_replacement_10_Jan_2019
#  Serco_07_Sept_2017
#  Serco_docs_for_Mike
#  SERCO_PERCEPTOR_DOCS
#  Shared_by_Pradeep_to_me_for_Aurion
#  share_market_and_sharepoint_pmi
#  SignEasy-Backup
#  Standard_work_unipart__8april19
#  Statement20191031.pdf
#  Statement_FEB2024_712562514.pdf
#  Steel_blue_boots_2.JPG
# 'Story Explanation and Vocabulary List.gsheet'
#  Tax_Australia
#  Tax_Australia_2018_2019
#  Tax_Australia_2020
#  Tax_Australia_2021_filed_in_2022
#  Tax_Australia_2022_filed_in_2023
#  Tax_bankStatements
#  test_data_collection.gform
#  TFN_Ashok_Tax_File_Number_Australia.pdf
#  theletter
# 'This looks great. Instead of paragraph write bull....gdoc'
#  Toyota_camry_2020_2021_renew
#  Toyota_camry_car_insurance_2018_renew
#  Toyota_RENEW_QBE_REGO_NMA_insurance_2019_10
#  Travel_India_24_jan_17
#  Udacity_k_best_machine_learning_scores_29_Nov_2018_Asha.xlsx
#  udemy_courses
# 'Underwriter_Application_Mr John Smith'
#  Unipart_work
# 'Untitled document (1).gdoc'
# 'Untitled document (2).gdoc'
# 'Untitled document (3).gdoc'
# 'Untitled document (4).gdoc'
# 'Untitled document (5).gdoc'
# 'Untitled document (6).gdoc'
# 'Untitled document (7).gdoc'
# 'Untitled document (8).gdoc'
# 'Untitled document.gdoc'
# 'Untitled form.gform'
# 'Untitled spreadsheet.gsheet'
#  westernunion_googledrive
#  willoughby_council
# 'Копия "Green Weekly Meal Planner".gsheet'

# %%
from google.colab import drive
drive.mount('/content/drive')

# Now find it
# !ls "/content/drive/MyDrive/"

# Search for point cloud files
# !find "/content/drive/MyDrive" -maxdepth 3 -name "*.las" -o -name "*.ply" -o -name "*.pcd" -o -name "*.xyz" 2>/dev/null | head -20
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# '~$Udacity_k_best_machine_learning_scores_29_Nov_2018_Asha.xlsx'
#  AAAA_Prisha_Google_Drive_17_Sept_25
#  AAA_Ashok_Durga_Transport
# 'Air India Web Booking eTicket (NHN2VW) - ASHOK.pdf'
#  airtel_recharge
#  Ajay
#  A_machine_learning_after_indexing
# 'Appendix 2.1g Re-enrolment Form 2024.docx'
#  ASHA_CBA
#  Asha_CBA_Appraisal
#  ASHA_CBA_IOS
#  Asha_CBA_last_working_day
#  Asha_CBA_Offer_Letter_Lead_2021
#  Asha_Citiban_KYC_17_May_20
#  Asha_Google_drive
#  Asha_google_interview_20_May_19.xlsx
# 'Asha ICICI'
#  Asha_Issrani_Chapter_lead.gdoc
# 'ASHA ISSRANI PAYMENT METHODS 2024.pdf'
#  Asha_Issrani_Renewal_Passport_Sydney_MArch_2018
#  Asha_Pixel_return
# 'Asha_updated_Resume_Specialist_with ITS.gdoc'
#  Ashok_certificates
#  Ashok_hdfc
# 'Ashok-Job Application N8n-Agent - Tracker.gsheet'
#  Ashok_New_passport_Application
#  Ashok_old_images
#  Ashok_PMP_Maths.docx
#  Ashok_sydney_live_events
#  August_jobs_2018
# 'Balloon voucher adrenaline '
# 'based on the sructure in the word file attached c....gsheet'
#  Bhawna_employer_insurance_Feb_18
#  Bias
#  Bot_Experiment_Noble_Oak
#  Bupa_payments
# 'by_four_LORD Ganesh Ji Aarti.docx'
#  Canada_bay_council
# 'Can just give Area and growth percentage table on... (1).gsheet'
# 'Can just give Area and growth percentage table on....gsheet'
# 'Can you give a the list in the form of a 2 column... (1).gsheet'
# 'Can you give a the list in the form of a 2 column....gsheet'
# 'Can you give list of risks and their mitigation i....gsheet'
# 'Can you give  list of stakeholders and and their....gsheet'
# 'can you give me word count for it.gdoc'
# 'Can you read the below and give me story board fo....gsheet'
# 'Can you write a description column right next to....gsheet'
#  CBA_PaySlips.zip
#  CCS_income_estimate
#  Central_academy_hemant
#  central_coast_council
#  Chatkaaz_test.gsheet
#  chatkazz
#  Chatkazz
#  ChatkazzDoorHAng.png
#  Cloud_strategy
#  club
# 'Colab Notebooks'
#  Continuous_Improvement_Projects_Manager_04_Dec_2018_AC_MFG_med.doc
#  Continuous_Improvement_Projects_Manager_Ashok_Mulchandani_04_Dec_2018_AC_MFG_med.doc
#  Continuous_Improvement_Proje.textClipping
#  Continuous_Improvement_specialist_Manager_Ashok_Mulchandani_05_Dec_2018_NM_AC_BA_MFG.doc
# 'Copy of SWOT Analysis Background PPT Template.gslides'
# 'Copy of SWOT Analysis for Employees.pptx'
# 'Copy of SWOT Analysis for Students.pptx'
# 'Copy of Swot Analysis for Training and Development PPT  (1).gslides'
# "Couldn't find it can you highlight that what you....gdoc"
#  Cover_letter_Ashok
#  Discussion_with_HArvey_nornam_interview_31_july_2019_IMG_1991.JPG
#  DMAIC.pdf
#  Driving_license_renew_ashok_25_dec_19
#  dropbox_01_dec_2017
#  dropbox_28_june_2017
#  Durga_Payments_required
#  durga_transport
#  e_companies_Business_name
#  educate_child
#  EN-us-drchuck
# 'Epson Connect'
#  Exercise_New_Zealnd
# 'Expense sheet Cricket match India Vs Aus.gsheet'
# 'Explore and develop'
#  facebook
#  Fingal_Bay_Expense_Ashok.gsheet
# 'first day of the rain.gdoc'
#  firststate_super
#  First_state_super
#  fiverr
#  flybuys_redeem
#  from_linda_M_property_waitara
#  FSPR
# 'GE_Senior System Architect (non IT) job in Greenville, South Carolina, United States _ Product Management jobs at GE.pdf'
# 'Google AI Studio'
# 'google personalisation products overview.mp4'
# 'Home Expense.gsheet'
#  HomeFoo
#  HomeFoo.mp4
#  HR_block_consent
#  ICICI_FATCA_25_april_2019
# 'Identify main stakeholders and explain how your t....gsheet'
#  iitm
#  IIT_Madras_fee_Ashok_Jan_May_2021_3100_paid_14_march_21.pdf
# 'IIT_remote_proxy_Remote Proxy Setup _ P.G. Senapathy center for computing resource.pdf'
#  IMG_20250425_104817.jpg
# 'IMMI Grant Notification.pdf'
#  India_Singapore_travel_18_Oct_2019
# 'I need to file LCA as I am an australian citizen....gdoc'
# 'In the table above you  have made with clause and... (1).gsheet'
# 'In the table above you  have made with clause and....gsheet'
#  Iphone_7Plus_Ashok_contacts_vcf_768
#  ISO_9001:2008_manual
#  itrainer1360_shut_27_sept_2018
#  Jeet_bhawana_Ashok_Mutual
#  Jeetmulchandani_gmail_contact_list
#  Jitendra_Aditya_birla_SIP_reversal_19_Nov_2018.pdf
#  Jitu_krisha_30_oct_2019
#  Justice_NSW_13_June_2018
#  karma
#  LIC_receipts
#  Line_Site_Assessment_Report_Linen_15_july_2015_REV_1.pptx
#  Linkedin_Downloads
#  linkedin_image_19_aug_20
# 'LORD Ganesh Ji Aarti.docx'
# 'L&T_payslip'
#  Machine_learning
# 'Managing risks is paramount in construction proje....gsheet'
#  mars_wrigley_asquith
# 'meaning of my words'
# 'meanings of words'
# 'meanings of words (1)'
#  Misceleneous
#  MISCELLENEOUS_GOOGLE_DRIVE
#  Monaval_Night_market_expense.gsheet
#  Movie_twinkle_asha_drive
#  mri20aurion
#  mundan_prisha_11_Dec_17
#  MY_HP-laptop
# 'my letter.gdoc'
# 'my mother'
#  n8n_test
# 'Nirvi Mulchandani Developmental Summary May 2024.docx'
#  NishitAPK
#  Non_filing_of_income_tax_india_29_march_2018
#  opt_out_ehealth_Australia
#  Others_when_required
#  PanelCourseDetails_Ashok_marksheet_IIT_madard_17_July_2020_.pdf
#  papa_driving_license_renewal_march_2018
#  Papa_fortis_jaipur
#  PaymentStatus_jan_may_2020_iit_madras_declined.pdf
#  PaymentStatus_jan_may_2020_iit_madras_success_15_feb_2020.pdf
# 'Photogrammetry VS LiDAR Data Sets'
#  Physical_Activity_Australia
#  Pianorama-Junior-Course-Book-4-MP3s.zip
#  pizza
# 'Please convert this into a bar graph with labales.gsheet'
# 'Please the infromation below Armadale'$'\t''VIC'$'\t''3143'$'\n''Br....gsheet'
#  Ponytail
#  presentation_IO_AI_tool.gslides
# 'Prisha2nd Birthday.mp4'
#  prisha_birthday_2020_3_years
#  Prisha_Cake_Smash
#  Prisha_cake_smash_photo_high_res_Jan_18
#  Prisha_Dance_class_enrollment
#  Prisha_Dec_2018_exlore_and_develop
#  Prisha_Folder_Rainbow
#  Prisha_KU_wahroonga
#  Prisha_Next_Generation_day_care_27_May_2017
#  Prisha_photoshoot_Sept_2017
#  Prisha_Piano_ISM_turramurra
#  Prisha_rhythmic
#  Prisha_School_forms_Waitara
#  Prisha_Singing-Sargam.gdoc
# "Prisha's_Medical_records"
#  Prisha_swim_barker
#  PSD
#  Python_Assignments
#  Rajasthan_health_2020
#  RENEW_DL_2019_Asha_Ashok
#  Research_IOT
#  RRV_Australia_Asha_Ashok_15_Sept_2019
#  Salvation_Army
#  sbi_card_24_dec_2019
#  sbicard_googledrive_24_Sept_17
#  SBI_payments_July_2020
#  Seagate_hardrive_replacement_10_Jan_2019
#  Serco_07_Sept_2017
#  Serco_docs_for_Mike
#  SERCO_PERCEPTOR_DOCS
#  Shared_by_Pradeep_to_me_for_Aurion
#  share_market_and_sharepoint_pmi
#  SignEasy-Backup
#  Standard_work_unipart__8april19
#  Statement20191031.pdf
#  Statement_FEB2024_712562514.pdf
#  Steel_blue_boots_2.JPG
# 'Story Explanation and Vocabulary List.gsheet'
#  Tax_Australia
#  Tax_Australia_2018_2019
#  Tax_Australia_2020
#  Tax_Australia_2021_filed_in_2022
#  Tax_Australia_2022_filed_in_2023
#  Tax_bankStatements
#  test_data_collection.gform
#  TFN_Ashok_Tax_File_Number_Australia.pdf
#  theletter
# 'This looks great. Instead of paragraph write bull....gdoc'
#  Toyota_camry_2020_2021_renew
#  Toyota_camry_car_insurance_2018_renew
#  Toyota_RENEW_QBE_REGO_NMA_insurance_2019_10
#  Travel_India_24_jan_17
#  Udacity_k_best_machine_learning_scores_29_Nov_2018_Asha.xlsx
#  udemy_courses
# 'Underwriter_Application_Mr John Smith'
#  Unipart_work
# 'Untitled document (1).gdoc'
# 'Untitled document (2).gdoc'
# 'Untitled document (3).gdoc'
# 'Untitled document (4).gdoc'
# 'Untitled document (5).gdoc'
# 'Untitled document (6).gdoc'
# 'Untitled document (7).gdoc'
# 'Untitled document (8).gdoc'
# 'Untitled document.gdoc'
# 'Untitled form.gform'
# 'Untitled spreadsheet.gsheet'
#  westernunion_googledrive
#  willoughby_council
# 'Копия "Green Weekly Meal Planner".gsheet'

# %%
# Try this (adjust the path to match your folder name)
# !find "/content/drive/MyDrive/Photogrammetry VS LiDAR Data Sets" -maxdepth 2 -name "*.las" -o -name "*.ply" -o -name "*.pcd" -o -name "*.xyz" -o -name "*.bin" 2>/dev/null | head -20

# %%
# !ls "/content/drive/MyDrive/Photogrammetry VS LiDAR Data Sets/"
# Out:
# 'LiDAR Data'  'Photogrammetry Data'

# %%
# !ls "/content/drive/MyDrive/Photogrammetry VS LiDAR Data Sets/LiDAR Data/Urban Data"
# Out:
# AT  dumps  lidars  sentry_database

# %%
# !find "/content/drive/MyDrive/Photogrammetry VS LiDAR Data Sets/" -maxdepth 3 -type d
# Out:
# /content/drive/MyDrive/Photogrammetry VS LiDAR Data Sets/
# /content/drive/MyDrive/Photogrammetry VS LiDAR Data Sets/Photogrammetry Data
# /content/drive/MyDrive/Photogrammetry VS LiDAR Data Sets/Photogrammetry Data/Urban Data
# /content/drive/MyDrive/Photogrammetry VS LiDAR Data Sets/Photogrammetry Data/Urban Data/dumps
# /content/drive/MyDrive/Photogrammetry VS LiDAR Data Sets/Photogrammetry Data/Urban Data/AT
# /content/drive/MyDrive/Photogrammetry VS LiDAR Data Sets/Photogrammetry Data/Urban Data/map
# /content/drive/MyDrive/Photogrammetry VS LiDAR Data Sets/Photogrammetry Data/Urban Data/images
# /content/drive/MyDrive/Photogrammetry VS LiDAR Data Sets/Photogrammetry Data/Urban Data/models
# /content/drive/MyDrive/Photogrammetry VS LiDAR Data Sets/Photogrammetry Data/Vegetation Data
# /content/drive/MyDrive/Photogrammetry VS LiDAR Data Sets/Photogrammetry Data/Vegetation Data/AT
# /content/drive/MyDrive/Photogrammetry VS LiDAR Data Sets/Photogrammetry Data/Vegetation Data/dumps
# /content/drive/MyDrive/Photogrammetry VS LiDAR Data Sets/Photogrammetry Data/Vegetation Data/images
# /content/drive/MyDrive/Photogrammetry VS LiDAR Data Sets/Photogrammetry Data/Vegetation Data/models
# /content/drive/MyDrive/Photogrammetry VS LiDAR Data Sets/Photogrammetry Data/Vegetation Data/map
# /content/drive/MyDrive/Photogrammetry VS LiDAR Data Sets/LiDAR Data
# /content/drive/MyDrive/Photogrammetry VS LiDAR Data Sets/LiDAR Data/Urban Data
# /content/drive/MyDrive/Photogrammetry VS LiDAR Data Sets/LiDAR Data/Urban Data/AT
# /content/drive/MyDrive/Photogrammetry VS LiDAR Data Sets/LiDAR Data/Urban Data/sentry_database
# /content/drive/MyDrive/Photogrammetry VS LiDAR Data Sets/LiDAR Data/Urban Data/dumps
# /content/drive/MyDrive/Photogrammetry VS LiDAR Data Sets/LiDAR Data/Urban Data/lidars
# /content/drive/MyDrive/Photogrammetry VS LiDAR Data Sets/LiDAR Data/Vegetation Data
# /content/drive/MyDrive/Photogrammetry VS LiDAR Data Sets/LiDAR Data/Vegetation Data/sentry_database
# /content/drive/MyDrive/Photogrammetry VS LiDAR Data Sets/LiDAR Data/Vegetation Data/lidars
# /content/drive/MyDrive/Photogrammetry VS LiDAR Data Sets/LiDAR Data/Vegetation Data/AT
# /content/drive/MyDrive/Photogrammetry VS LiDAR Data Sets/LiDAR Data/Vegetation Data/dumps

# %%
# !find "/content/drive/MyDrive/Photogrammetry VS LiDAR Data Sets/" -name "*.las" -o -name "*.laz" -o -name "*.ply" -o -name "*.pcd" -o -name "*.xyz" -o -name "*.e57" 2>/dev/null | head -30

# %%
# Check LiDAR data files
# !ls "/content/drive/MyDrive/Photogrammetry VS LiDAR Data Sets/LiDAR Data/Urban Data/lidars/"

# %%
# Find ALL files with extensions
# !find "/content/drive/MyDrive/Photogrammetry VS LiDAR Data Sets/" -type f | grep -E "\.(las|laz|ply|pcd|xyz|e57|obj|pts|bin|tif)" | head -30
